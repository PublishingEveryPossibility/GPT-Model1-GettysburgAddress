# %%
# !pip install requests

import requests
import json

# Replace the placeholder below with your actual key:
api_key = 'AIzaSyDs4vw4YyEy0t4yirTHNNkLrm_KHNvZimE'

# Correct API URL structure for Google Gemini API: key passed as a query parameter
api_url = f'https://generativelanguage.googleapis.com/v1/models/gemini-2.5-flash:generateContent?key={api_key}'

# Headers for Google Gemini API
headers = {
    'Content-Type': 'application/json'
}

# Define the input prompt for the first request
prompt = "Explain the meaning of the following text from Lincoln's Gettysburg Address: 'Four score and seven years ago our fathers brought forth on this continent, a new nation, conceived in Liberty, and dedicated to the proposition that all men are created equal.' "

# Define the CORRECTED request payload for Gemini API
data = {
    "contents": [
        {
            "parts": [
                {"text": prompt}
            ]
        }
    ],
    "generationConfig": {
        # ⬅️ INCREASED SIGNIFICANTLY: To eliminate MAX_TOKENS as a real issue
        "maxOutputTokens": 9000,
        "temperature": 1
    }
}

print("--- Running First Request (Gettysburg Address Explanation) ---")
# Make the request
response = requests.post(api_url, headers=headers, json=data)

# Parse the response
if response.status_code == 200:
    response_json = response.json()
    # Simplified check to see if content exists and has text
    try:
        response_text = response_json["candidates"][0]["content"]["parts"][0]["text"]
        print("Generated Response:", response_text)
    except (KeyError, IndexError):
        print("Success (200), but no content was generated or candidates structure is incomplete.")
        print(f"Model Finish Reason: {response_json['candidates'][0].get('finishReason', 'N/A')}")
        # Print the full response for debugging if needed
        # print("Full Response:", response_json) 
else:
    print(f"Error: {response.status_code}. Response: {response.text}")


# ----------------------------------------------------------------------
## Step 4: Running Text Summarization

summary_prompt = "Summarize the Gettysburg Address in 50 words."

# Modify the data for summarization
data["contents"][0]["parts"][0]["text"] = summary_prompt
# Using a higher max output to ensure the 50 words are not prematurely cut
data["generationConfig"]["maxOutputTokens"] = 50 

print("\n--- Running Second Request (Summarization) ---")
# Send a request for summarization
response = requests.post(api_url, headers=headers, json=data)

# Parse the response for summary
if response.status_code == 200:
    response_json = response.json()
    try:
        response_summary = response_json["candidates"][0]["content"]["parts"][0]["text"]
        print("Summary:", response_summary)
    except (KeyError, IndexError):
        print("Success (200), but no content was generated or candidates structure is incomplete.")
        print(f"Model Finish Reason: {response_json['candidates'][0].get('finishReason', 'N/A')}")
        # print("Full Response:", response_json)
else:
    print(f"Error: {response.status_code}. Response: {response.text}")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# --- Running First Request (Gettysburg Address Explanation) ---
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Generated Response: This opening sentence from Abraham Lincoln's Gettysburg Address is incredibly rich and dense with meaning, setting the stage for the entire speech. Let's break it down phrase by phrase:
#
# 1.  **"Four score and seven years ago"**
#     *   **"Score"** is an old-fashioned unit meaning twenty. So, "four score" is 80, plus "seven" equals 87 years.
#     *   **Context:** The Gettysburg Address was delivered in November 1863. Counting back 87 years from 1863 brings us precisely to **1776**.
# ...

# %%
# !pip install requests

import requests
import json

api_key = 'AIzaSyDs4vw4YyEy0t4yirTHNNkLrm_KHNvZimE'

api_url = f'https://generativelanguage.googleapis.com/v1/models/gemini-2.5-flash:generateContent?key={api_key}'

headers = {
    'Authorization': f'Bearer {api_key}',
    'Content-Type': 'application/json'
}


prompt = "Explain the meaning of the following text from Lincoln's Gettysburg Address: 'Four score and seven years ago our fathers brought forth on this continent, a new nation, conceived in Liberty, and dedicated to the proposition that all men are created equal.'"


data = {
    "prompt": prompt,
    "max_tokens": 2000,
    "temperature": 0.7
}


response = requests.post(api_url, headers=headers, json=data)


if response.status_code == 200:
    response_text = response.json()["choices"][0]["text"]
    print("Generated Response:", response_text)
else:
    print("Error:", response.status_code, response.text)

summary_prompt = "Summarize the Gettysburg Address in 50 words."

data["prompt"] = summary_prompt
data["max_tokens"] = 50

response = requests.post(api_url, headers=headers, json=data)

if response.status_code == 200:
    response_summary = response.json()["choices"][0]["text"]
    print("Summary:", response_summary)
else:
    print("Error:", response.status_code, response.text)
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Error: 401 {
#   "error": {
#     "code": 401,
#     "message": "Request had invalid authentication credentials. Expected OAuth 2 access token, login cookie or other valid authentication credential. See https://developers.google.com/identity/sign-in/web/devconsole-project.",
#     "status": "UNAUTHENTICATED"
#   }
# }
#
# Error: 401 {
#   "error": {
#     "code": 401,
#     "message": "Request had invalid authentication credentials. Expected OAuth 2 access token, login cookie or other valid authentication credential. See https://developers.google.com/identity/sign-in/web/devconsole-project.",
#     "status": "UNAUTHENTICATED"
#   }
# }
